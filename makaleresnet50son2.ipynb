# %% [markdown]
# <a href="https://colab.research.google.com/github/hazelkozlu/CoreDemo/blob/master/makaleresnet50son2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#google drive bağlantısı için
from  google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/Colab Notebooks/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks

# %%
import numpy as np
import pandas as pd
import os, random, math, glob, cv2, pickle
from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.utils import shuffle
from sklearn.model_selection import  train_test_split
from keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix, classification_report

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure

# %%
import pandas as pd
import numpy as np
import os
import keras
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense,GlobalAveragePooling2D
from tensorflow.keras.applications import InceptionResNetV2, VGG16, ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD

# %%
import fnmatch
import numpy as np
from sklearn.utils import class_weight
y = []
class_names = ["yaprakdelen", "saglikli", "potasyumeksik", "kulleme"]

for class_name in class_names:
    y.extend([class_names.index(class_name) for _ in range(len(fnmatch.filter(os.listdir('TezVeriSeti/train/' + class_name), '*.png')))])

print(np.bincount(y))

from sklearn.utils.class_weight import compute_sample_weight
import numpy as np

# Sınıf ağırlıkları
class_weights = compute_sample_weight(class_weight='balanced', y=y)

# Sınıf ağırlıklarını sınıflara göre düzenle
class_weights_dict = dict(zip(range(4), np.unique(y, return_counts=True)[1] / np.bincount(y)))
print(class_weights_dict)
# Out:
# [240 240 240 238]
# {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0}

# %%
model_to_use='resnet50'

base_model=ResNet50(weights='imagenet',include_top=False)
for layer in base_model.layers:
    layer.trainable=False

x=base_model.output
x=GlobalAveragePooling2D()(x)
x=Dense(128,activation='relu')(x)
x=Dense(128,activation='relu')(x)
preds=Dense(4,activation='softmax')(x)

model=Model(inputs=base_model.input, outputs=preds)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
train_save= 'TezVeriSeti/train'
val_save = 'TezVeriSeti/valid'

#train
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
                                    rotation_range=15,
                                    shear_range=0.2,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    zoom_range=0.2,
                                    brightness_range=(0.1, 0.9),
                                    channel_shift_range=150.0,
                                    horizontal_flip=True)

train_generator=train_datagen.flow_from_directory(train_save,
                                                target_size=(224,224),
                                                color_mode='rgb',
                                                batch_size=16,
                                                class_mode='categorical',
                                                shuffle=True)
# val
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

val_generator=val_datagen.flow_from_directory(val_save,
                                                target_size=(224,224),
                                                color_mode='rgb',
                                                batch_size=16,
                                                class_mode='categorical',
                                                shuffle=False)
# Out:
# Found 958 images belonging to 4 classes.
# Found 960 images belonging to 4 classes.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=train_generator.n//train_generator.batch_size
step_size_val=val_generator.n//val_generator.batch_size

earlystop = EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint = ModelCheckpoint('model-epoch-{epoch:03d}-valacc-{val_accuracy:03f}.h5', verbose=1, monitor='val_accuracy',save_best_only=True, mode='auto')

no_epochs = 25
hist = model.fit(train_generator,
                   steps_per_epoch=step_size_train,
                   epochs=no_epochs,
                   validation_data=val_generator,
                   validation_steps=step_size_val,
                   callbacks=[earlystop, checkpoint], #callbacks=[checkpoint],
                   class_weight=class_weights_dict)
# Out:
# Epoch 1/25
# 59/59 [==============================] - ETA: 0s - loss: 0.8166 - accuracy: 0.6571
# Epoch 1: val_accuracy improved from -inf to 0.82604, saving model to model-epoch-001-valacc-0.826042.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 59/59 [==============================] - 515s 9s/step - loss: 0.8166 - accuracy: 0.6571 - val_loss: 0.4516 - val_accuracy: 0.8260
# Epoch 2/25
# 59/59 [==============================] - ETA: 0s - loss: 0.5360 - accuracy: 0.7749
# Epoch 2: val_accuracy did not improve from 0.82604
# 59/59 [==============================] - 395s 7s/step - loss: 0.5360 - accuracy: 0.7749 - val_loss: 0.8164 - val_accuracy: 0.7271
# Epoch 3/25
# 59/59 [==============================] - ETA: 0s - loss: 0.5419 - accuracy: 0.7643
# Epoch 3: val_accuracy did not improve from 0.82604
# 59/59 [==============================] - 400s 7s/step - loss: 0.5419 - accuracy: 0.7643 - val_loss: 0.5403 - val_accuracy: 0.7604
# Epoch 4/25
# 59/59 [==============================] - ETA: 0s - loss: 0.4973 - accuracy: 0.7972
# Epoch 4: val_accuracy improved from 0.82604 to 0.84792, saving model to model-epoch-004-valacc-0.847917.h5
# 59/59 [==============================] - 398s 7s/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.3968 - val_accuracy: 0.8479
# Epoch 5/25
# 59/59 [==============================] - ETA: 0s - loss: 0.4166 - accuracy: 0.8301
# Epoch 5: val_accuracy did not improve from 0.84792
# 59/59 [==============================] - 396s 7s/step - loss: 0.4166 - accuracy: 0.8301 - val_loss: 0.4559 - val_accuracy: 0.8115
# Epoch 6/25
# 59/59 [==============================] - ETA: 0s - loss: 0.4546 - accuracy: 0.7972
# Epoch 6: val_accuracy did not improve from 0.84792
# 59/59 [==============================] - 394s 7s/step - loss: 0.4546 - accuracy: 0.7972 - val_loss: 0.6084 - val_accuracy: 0.7354
# Epoch 7/25
# 59/59 [==============================] - ETA: 0s - loss: 0.4433 - accuracy: 0.8110
# Epoch 7: val_accuracy did not improve from 0.84792
# 59/59 [==============================] - 394s 7s/step - loss: 0.4433 - accuracy: 0.8110 - val_loss: 0.5243 - val_accuracy: 0.7573
# Epoch 8/25
# 59/59 [==============================] - ETA: 0s - loss: 0.4118 - accuracy: 0.8301
# Epoch 8: val_accuracy improved from 0.84792 to 0.88229, saving model to model-epoch-008-valacc-0.882292.h5
# 59/59 [==============================] - 389s 7s/step - loss: 0.4118 - accuracy: 0.8301 - val_loss: 0.3208 - val_accuracy: 0.8823
# Epoch 9/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3924 - accuracy: 0.8503
# Epoch 9: val_accuracy did not improve from 0.88229
# 59/59 [==============================] - 364s 6s/step - loss: 0.3924 - accuracy: 0.8503 - val_loss: 0.3366 - val_accuracy: 0.8677
# Epoch 10/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3726 - accuracy: 0.8471
# Epoch 10: val_accuracy did not improve from 0.88229
# 59/59 [==============================] - 390s 7s/step - loss: 0.3726 - accuracy: 0.8471 - val_loss: 0.3320 - val_accuracy: 0.8667
# Epoch 11/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3796 - accuracy: 0.8270
# Epoch 11: val_accuracy did not improve from 0.88229
# 59/59 [==============================] - 390s 7s/step - loss: 0.3796 - accuracy: 0.8270 - val_loss: 0.4271 - val_accuracy: 0.8260
# Epoch 12/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3732 - accuracy: 0.8482
# Epoch 12: val_accuracy did not improve from 0.88229
# 59/59 [==============================] - 389s 7s/step - loss: 0.3732 - accuracy: 0.8482 - val_loss: 0.4267 - val_accuracy: 0.8281
# Epoch 13/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3789 - accuracy: 0.8333
# Epoch 13: val_accuracy did not improve from 0.88229
# 59/59 [==============================] - 366s 6s/step - loss: 0.3789 - accuracy: 0.8333 - val_loss: 0.5179 - val_accuracy: 0.8000
# Epoch 14/25
# 59/59 [==============================] - ETA: 0s - loss: 0.4034 - accuracy: 0.8259
# Epoch 14: val_accuracy did not improve from 0.88229
# 59/59 [==============================] - 390s 7s/step - loss: 0.4034 - accuracy: 0.8259 - val_loss: 0.4363 - val_accuracy: 0.8188
# Epoch 15/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3545 - accuracy: 0.8546
# Epoch 15: val_accuracy improved from 0.88229 to 0.88437, saving model to model-epoch-015-valacc-0.884375.h5
# 59/59 [==============================] - 392s 7s/step - loss: 0.3545 - accuracy: 0.8546 - val_loss: 0.3132 - val_accuracy: 0.8844
# Epoch 16/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3719 - accuracy: 0.8270
# Epoch 16: val_accuracy improved from 0.88437 to 0.89792, saving model to model-epoch-016-valacc-0.897917.h5
# 59/59 [==============================] - 390s 7s/step - loss: 0.3719 - accuracy: 0.8270 - val_loss: 0.2613 - val_accuracy: 0.8979
# Epoch 17/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3311 - accuracy: 0.8662
# Epoch 17: val_accuracy did not improve from 0.89792
# 59/59 [==============================] - 391s 7s/step - loss: 0.3311 - accuracy: 0.8662 - val_loss: 0.4589 - val_accuracy: 0.8177
# Epoch 18/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3267 - accuracy: 0.8546
# Epoch 18: val_accuracy did not improve from 0.89792
# 59/59 [==============================] - 390s 7s/step - loss: 0.3267 - accuracy: 0.8546 - val_loss: 0.4996 - val_accuracy: 0.8167
# Epoch 19/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.8641
# Epoch 19: val_accuracy improved from 0.89792 to 0.90625, saving model to model-epoch-019-valacc-0.906250.h5
# 59/59 [==============================] - 392s 7s/step - loss: 0.3274 - accuracy: 0.8641 - val_loss: 0.2661 - val_accuracy: 0.9062
# Epoch 20/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3207 - accuracy: 0.8620
# Epoch 20: val_accuracy did not improve from 0.90625
# 59/59 [==============================] - 389s 7s/step - loss: 0.3207 - accuracy: 0.8620 - val_loss: 0.3705 - val_accuracy: 0.8583
# Epoch 21/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3198 - accuracy: 0.8684
# Epoch 21: val_accuracy did not improve from 0.90625
# 59/59 [==============================] - 391s 7s/step - loss: 0.3198 - accuracy: 0.8684 - val_loss: 0.3289 - val_accuracy: 0.8719
# Epoch 22/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3338 - accuracy: 0.8524
# Epoch 22: val_accuracy did not improve from 0.90625
# 59/59 [==============================] - 390s 7s/step - loss: 0.3338 - accuracy: 0.8524 - val_loss: 0.4268 - val_accuracy: 0.8479
# Epoch 23/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.8694
# Epoch 23: val_accuracy did not improve from 0.90625
# 59/59 [==============================] - 390s 7s/step - loss: 0.3364 - accuracy: 0.8694 - val_loss: 0.3223 - val_accuracy: 0.8896
# Epoch 24/25
# 59/59 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.8747
# Epoch 24: val_accuracy did not improve from 0.90625
# 59/59 [==============================] - 390s 7s/step - loss: 0.2885 - accuracy: 0.8747 - val_loss: 0.3446 - val_accuracy: 0.8760
# Epoch 25/25
# 59/59 [==============================] - ETA: 0s - loss: 0.3228 - accuracy: 0.8715
# Epoch 25: val_accuracy did not improve from 0.90625
# 59/59 [==============================] - 391s 7s/step - loss: 0.3228 - accuracy: 0.8715 - val_loss: 0.3646 - val_accuracy: 0.8708

# %%
# visualizing losses and accuracy
train_loss = hist.history['loss']
val_loss = hist.history['val_loss']
train_accu = hist.history['accuracy']
val_accu = hist.history['val_accuracy']
xc = range(len(train_loss))

plt.figure()
plt.plot(xc, train_loss, label='Training loss')
plt.plot(xc, val_loss, label='Validation loss')
plt.legend(loc="lower left")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.savefig('train_val_loss.png')
plt.show()

plt.figure()
plt.plot(xc, train_accu, label='Training accuracy')
plt.plot(xc, val_accu, label='Validation accuracy')
plt.legend(loc="lower left")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.savefig('train_val_accuracy.png')
plt.show()
from sklearn.metrics import confusion_matrix, classification_report

# Modelin doğrulama verileri üzerinde tahminlerini alın
y_pred = model.predict(val_generator, steps=step_size_val)
y_pred_classes = np.argmax(y_pred, axis=1)

# Gerçek etiketleri alın
y_true = val_generator.classes

# Karmaşıklık matrisini hesaplayın
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

# Karmaşıklık matrisini yazdırın
print("Confusion Matrix:")
print(confusion_mtx)

# Sınıflandırma raporunu hesaplayın ve yazdırın
class_report = classification_report(y_true, y_pred_classes, target_names=val_generator.class_indices)
print("\nClassification Report:\n", class_report)
# Out:
# 60/60 [==============================] - 180s 3s/step
# Confusion Matrix:
# [[240   0   0   0]
#  [  0 231   5   4]
#  [  0   5 222  13]
#  [  0  68  29 143]]
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#       kulleme       1.00      1.00      1.00       240
# potasyumeksik       0.76      0.96      0.85       240
#      saglikli       0.87      0.93      0.90       240
#   yaprakdelen       0.89      0.60      0.71       240
#
#      accuracy                           0.87       960
#     macro avg       0.88      0.87      0.86       960
#  weighted avg       0.88      0.87      0.86       960

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Karmaşıklık matrisini ısı haritası olarak çizin
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=val_generator.class_indices.keys(),
            yticklabels=val_generator.class_indices.keys())
plt.xlabel('Tahmin Edilen Etiket')
plt.ylabel('Gerçek Etiket')
plt.title('Karmaşıklık Matrisi')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-73a24cebadef> in <cell line: 6>()
#       4 # Karmaşıklık matrisini ısı haritası olarak çizin
#       5 plt.figure(figsize=(8, 6))
# ----> 6 sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', cbar=False,
#       7             xticklabels=val_generator.class_indices.keys(),
#       8             yticklabels=val_generator.class_indices.keys())
#
# NameError: name 'confusion_mtx' is not defined
